# %% [markdown]
# ![YouTubeNews](Images/youtube_news.png)

# %% [markdown]
# <h1><center>Social Media Bonanza: YouTube vs News</center></h1>
# <h4><center>Authors: Blake Freeman, Jill Smith, Tomeka Morrison, Trong Nguyen</center></h4>
# <p>What is the relationship between news and social media? In this project will we analyze news articles and YouTube posts to determine what articles stand out.</p>

# %%
import pandas as pd 
import numpy as np 
import pymongo
import datetime as dt
import matplotlib.pyplot as plt

# %% [markdown]
# <h3>Import Clean Data & Create DataFrames</h3>

# %%
# Load YouTube data (clean) and Articles data (clean)
youtube_csv = ('Resources/YouTube_Clean.csv')
articles_csv = ('Resources/Articles_Clean_v2.csv')

# %%
# Convert YouTube Data into DataFrame 
youtube_df = pd.read_csv(youtube_csv)
youtube_df.head()
# Out:
#    Category_ID         Category        Date  \
# 0           22   People & Blogs  2017-11-14
# 1           22   People & Blogs  2017-11-14
# 2           22   People & Blogs  2017-11-14
# 3           22   People & Blogs  2017-11-14
# 4           22   People & Blogs  2017-11-14
#
#                                          Video_Title             Channel  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE        CaseyNeistat
# 1                               Me-O Cats Commercial             Nobrand
# 2  AFFAIRS, EX BOYFRIENDS, $18MILLION NET WORTH -...  Shawn Johnson East
# 3  BLIND(folded) CAKE DECORATING CONTEST (with Mo...        Grace Helbig
# 4      Wearing Online Dollar Store Makeup For A Week      Safiya Nygaard
#
#                                                 Tags  Total_Views  \
# 0                                    SHANtell martin       748374
# 1                          cute|"cats"|"thai"|"eggs"        98966
# 2  shawn johnson|"andrew east"|"shawn east"|"shaw...       321053
# 3  itsgrace|"funny"|"comedy"|"vlog"|"grace"|"helb...       197062
# 4  wearing online dollar store makeup for a week|...      2744430
#
#    Total_Likes  Comments_Count
# 0        57527           15954
# 1         2486             532
# 2         4451             895
# 3         7250             456
# 4       115426            6541

# %%
# Convert Articles Data into DataFrame 
articles_df = pd.read_csv(articles_csv)
articles_df.head()
# Out:
#                  Article_ID  \
# 0  5a7101c110f40f00018be961
# 1  5a70fc1210f40f00018be950
# 2  5a70f8f810f40f00018be943
# 3  5a70eb8110f40f00018be925
# 4  5a70d1d210f40f00018be8d9
#
#                                             Headline  \
# 0  Rhythm of the Streets: ‘We’re Warrior Women, a...
# 1          As Deficit Grows, Congress Keeps Spending
# 2                       Lesson in Select Bus Service
# 3                 Here’s the Real State of the Union
# 4                       Good Riddance to Chief Wahoo
#
#                                             Keywords     News_Category  \
# 0  ['Bahia (Brazil)', 'Music', 'Women and Girls',...   Travel & Events
# 1  ['United States Politics and Government', 'Fed...   News & Politics
# 2  ['Buses', 'Pennsylvania Station (Manhattan, NY...   News & Politics
# 3  ['State of the Union Message (US)', 'Trump, Do...    People & Blogs
# 4  ['Baseball', 'Cleveland Indians', 'Western Res...    People & Blogs
#
#           Pub_Date Section_Name  \
# 0  1/30/2018 23:37      Unknown
# 1  1/30/2018 23:13     Politics
# 2  1/30/2018 23:00      Unknown
# 3  1/30/2018 22:02   Editorials
# 4  1/30/2018 20:13      Unknown
#
#                                              Snippet Media_Type  \
# 0  Meet the all-female Brazilian drum group that ...       News
# 1  Treasury Secretary Steven Mnuchin urged Congre...       News
# 2  A woman finds out what happens when you don’t ...       News
# 3  The reaction against his authoritarian impulse...  Editorial
# 4  I’ve lived in Cleveland all my life, and I’m g...      Op-Ed
#
#                                                  URL
# 0  https://www.nytimes.com/2018/01/30/travel/braz...
# 1  https://www.nytimes.com/2018/01/30/us/politics...
# 2  https://www.nytimes.com/2018/01/30/nyregion/me...
# 3  https://www.nytimes.com/2018/01/30/opinion/edi...
# 4  https://www.nytimes.com/2018/01/30/opinion/chi...

# %%
articles_df.columns = ['Article_ID', 'Headline', 'Keywords', 'Category', 'Date',
       'Section_Name', 'Snippet', 'Media_Type', 'URL']
articles_df.head()
# Out:
#                  Article_ID  \
# 0  5a7101c110f40f00018be961
# 1  5a70fc1210f40f00018be950
# 2  5a70f8f810f40f00018be943
# 3  5a70eb8110f40f00018be925
# 4  5a70d1d210f40f00018be8d9
#
#                                             Headline  \
# 0  Rhythm of the Streets: ‘We’re Warrior Women, a...
# 1          As Deficit Grows, Congress Keeps Spending
# 2                       Lesson in Select Bus Service
# 3                 Here’s the Real State of the Union
# 4                       Good Riddance to Chief Wahoo
#
#                                             Keywords          Category  \
# 0  ['Bahia (Brazil)', 'Music', 'Women and Girls',...   Travel & Events
# 1  ['United States Politics and Government', 'Fed...   News & Politics
# 2  ['Buses', 'Pennsylvania Station (Manhattan, NY...   News & Politics
# 3  ['State of the Union Message (US)', 'Trump, Do...    People & Blogs
# 4  ['Baseball', 'Cleveland Indians', 'Western Res...    People & Blogs
#
#               Date Section_Name  \
# 0  1/30/2018 23:37      Unknown
# 1  1/30/2018 23:13     Politics
# 2  1/30/2018 23:00      Unknown
# 3  1/30/2018 22:02   Editorials
# 4  1/30/2018 20:13      Unknown
#
#                                              Snippet Media_Type  \
# 0  Meet the all-female Brazilian drum group that ...       News
# 1  Treasury Secretary Steven Mnuchin urged Congre...       News
# 2  A woman finds out what happens when you don’t ...       News
# 3  The reaction against his authoritarian impulse...  Editorial
# 4  I’ve lived in Cleveland all my life, and I’m g...      Op-Ed
#
#                                                  URL
# 0  https://www.nytimes.com/2018/01/30/travel/braz...
# 1  https://www.nytimes.com/2018/01/30/us/politics...
# 2  https://www.nytimes.com/2018/01/30/nyregion/me...
# 3  https://www.nytimes.com/2018/01/30/opinion/edi...
# 4  https://www.nytimes.com/2018/01/30/opinion/chi...

# %%
merge_df = pd.merge(youtube_df, articles_df, on='Category', suffixes=('_youtube', '_ny_times'))
merge_df.head()
# Out:
#    Category_ID         Category Date_youtube  \
# 0           22   People & Blogs   2017-11-14
# 1           22   People & Blogs   2017-11-14
# 2           22   People & Blogs   2017-11-14
# 3           22   People & Blogs   2017-11-14
# 4           22   People & Blogs   2017-11-14
#
#                           Video_Title       Channel             Tags  \
# 0  WE WANT TO TALK ABOUT OUR MARRIAGE  CaseyNeistat  SHANtell martin
# 1  WE WANT TO TALK ABOUT OUR MARRIAGE  CaseyNeistat  SHANtell martin
# 2  WE WANT TO TALK ABOUT OUR MARRIAGE  CaseyNeistat  SHANtell martin
# 3  WE WANT TO TALK ABOUT OUR MARRIAGE  CaseyNeistat  SHANtell martin
# 4  WE WANT TO TALK ABOUT OUR MARRIAGE  CaseyNeistat  SHANtell martin
#
#    Total_Views  Total_Likes  Comments_Count                Article_ID  \
# 0       748374        57527           15954  5a70eb8110f40f00018be925
# 1       748374        57527           15954  5a70d1d210f40f00018be8d9
# 2       748374        57527           15954  5a70c57b10f40f00018be8ac
# 3       748374        57527           15954  5a704e5a10f40f00018be726
# 4       748374        57527           15954  5a704cbc10f40f00018be721
#
#                              Headline  \
# 0  Here’s the Real State of the Union
# 1        Good Riddance to Chief Wahoo
# 2  How Trump’s Critics Should Respond
# 3                             Unknown
# 4     The Latest Data Privacy Debacle
#
#                                             Keywords    Date_ny_times  \
# 0  ['State of the Union Message (US)', 'Trump, Do...  1/30/2018 22:02
# 1  ['Baseball', 'Cleveland Indians', 'Western Res...  1/30/2018 20:13
# 2  ['United States Politics and Government', 'Sta...  1/30/2018 19:20
# 3  ['Terrorism', 'Politics and Government', 'Civi...  1/30/2018 10:52
# 4  ['Data Storage', 'Privacy', 'Mobile Applicatio...  1/30/2018 10:45
#
#   Section_Name                                            Snippet Media_Type  \
# 0   Editorials  The reaction against his authoritarian impulse...  Editorial
# 1      Unknown  I’ve lived in Cleveland all my life, and I’m g...      Op-Ed
# 2      Unknown  The normalcy of a State of the Union address s...      Op-Ed
# 3    The Daily  After the U.S. government said it would cut mi...   briefing
# 4      Unknown  The saga of Strava, an app that inadvertently ...      Op-Ed
#
#                                                  URL
# 0  https://www.nytimes.com/2018/01/30/opinion/edi...
# 1  https://www.nytimes.com/2018/01/30/opinion/chi...
# 2  https://www.nytimes.com/2018/01/30/opinion/tru...
# 3  https://www.nytimes.com/2018/01/30/podcasts/th...
# 4  https://www.nytimes.com/2018/01/30/opinion/str...

# %% [markdown]
# <h3>Upload Merged DataFrame to MongoDB</h3>

# %%
# connecting to mongo database
conn = 'mongodb://localhost:27017/Social_Media_DB'
client = pymongo.MongoClient(conn)
db = client.socialmedia_db
socialmedia = db.socialmedia.find()
client.db.socialmedia.insert_many(merge_df.to_dict(orient = 'records'))

# %% [markdown]
# <h3>Visualizations</h3>

# %%
# Look at the cateories
yt_group = youtube_df.groupby('Category')
count_yt= yt_group['Category'].count()
count_yt
# Out:
# Category
#  Autos & Vehicles          384
#  Comedy                   3457
#  Education                1656
#  Entertainment            9964
#  Film & Animation         2345
#  Gaming                    817
#  Howto & Style            4146
#  Music                    6472
#  News & Politics          2487
#  Nonprofits & Activism      57
#  People & Blogs           3210
#  Pets & Animals            920
#  Science & Technology     2401
#  Shows                      57
#  Sports                   2174
#  Travel & Events           402
# Name: Category, dtype: int64

# %%
# Create Bar Chart
count_chart = count_yt.plot(kind='bar')
plt.show()
plt.tight_layout()
